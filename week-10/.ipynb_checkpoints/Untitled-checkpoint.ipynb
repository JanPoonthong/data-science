# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.neighbors import KNeighborsClassifier
churn_df = pd.read_csv("data_sets/churn_df.csv", index_col=0)
churn_df.head()
# Out:
#    account_length  total_day_charge  total_eve_charge  total_night_charge  \
# 0             101             45.85             17.65                9.64
# 1              73             22.30              9.05                9.98
# 2              86             24.62             17.53               11.49
# 3              59             34.73             21.02                9.66
# 4             129             27.42             18.75               10.11
#
#    total_intl_charge  customer_service_calls  churn
# 0               1.22                       3      1
# 1               2.75                       2      0
# 2               3.13                       4      0
# 3               3.24                       1      0
# 4               2.59                       1      0

# %%
x = churn_df[["total_day_charge", "total_eve_charge"]].values
y = churn_df["churn"].values

print(x.shape, y.shape)
# Out:
# (3333, 2) (3333,)

# %%
knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(x, y)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
x_new = np.array([
    [56.8, 17.5],
    [24.4, 24.1],
    [50.1, 10.9],
    [200, 100],
    [300, 100]

])

print(x_new.shape)
# Out:
# (5, 2)

# %%
prediction = knn.predict(x_new)
print("Prediction: {}".format(prediction))
# Out:
# Prediction: [1 0 0 1 1]

# %%
x = churn_df[["account_length", "customer_service_calls"]].values
y = churn_df["churn"].values

knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(x, y)

x_new = np.array([
    [30.0, 17.5], 
    [107.0, 24.1],
    [213.0, 10.9]
])

prediction = knn.predict(x_new)
print("Prediction: {}".format(prediction))


from sklearn.model_selection import train_test_split

'''
It is best practice to ensure our split reflects the proportion of 
labels in our data. So if churn occurs in 10% of observations, we 
want 10% of labels in our training and test sets to represent 
churn. We achieve this by setting stratify equal to y.
'''

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=21, stratify=y)

knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(x_train, y_train)
print(knn.score(x_test, y_test))
# Out:
# Prediction: [0 1 0]
# 0.858

# %%
train_accuracies = {} 
test_accuracies = {} 
neighbors = np.arange(1,26) 

for neighbor in neighbors:
    knn = KNeighborsClassifier(n_neighbors=neighbor)
    knn.fit(x_train,y_train)
    train_accuracies[neighbor] = knn.score(x_train, y_train)
    test_accuracies[neighbor] = knn.score(x_test, y_test)
    
# print(train_accuracies.values()) 
# print(test_accuracies.values())

my_train = list(train_accuracies.values()) 
my_test = list(test_accuracies.values())

plt.figure(figsize=(8,6))

plt.title('KNN: Varing Number of Neighbors') 
plt.plot(neighbors, my_train, label='Training Accuracy') 
plt.plot(neighbors, my_test, label='Testing Accuracy') 

plt.legend()
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.show()

# %%
churn_df = pd.read_csv("data_sets/churn_df.csv", index_col=0)

from sklearn.model_selection import train_test_split

x = churn_df.drop("churn", axis=1).values
y = churn_df["churn"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
print(knn.score(x_test, y_test))
# Out:
# 0.8740629685157422

# %%
train_accuracies = {} 
test_accuracies = {} 
neighbors = np.arange(1,12) 

for neighbor in neighbors:
    knn = KNeighborsClassifier(n_neighbors=neighbor)
    knn.fit(x_train,y_train)
    train_accuracies[neighbor] = knn.score(x_train, y_train)
    test_accuracies[neighbor] = knn.score(x_test, y_test)
    
# print(train_accuracies.values()) 
# print(test_accuracies.values())

my_train = list(train_accuracies.values()) 
my_test = list(test_accuracies.values())

plt.figure(figsize=(8,6))

plt.title('KNN: Varing Number of Neighbors') 
plt.plot(neighbors, my_train, label='Training Accuracy') 
plt.plot(neighbors, my_test, label='Testing Accuracy') 

plt.legend()
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.show()

#K = around 10

# %%
diabetes_df = pd.read_csv("data_sets/diabetes.csv", index_col=0)
diabetes_df.head()
# Out:
#    pregnancies  glucose  triceps  insulin   bmi  age  diabetes
# 0            6      148       35        0  33.6   50         1
# 1            1       85       29        0  26.6   31         0
# 2            8      183        0        0  23.3   32         1
# 3            1       89       23       94  28.1   21         0
# 4            0      137       35      168  43.1   33         1

# %%
diabetes_df = pd.read_csv('data_sets/diabetes.csv', index_col = 0)

print(diabetes_df.shape)

X = diabetes_df.drop('glucose', axis=1).values

y = diabetes_df['glucose'].values

X_bmi = X[:,3]

X_bmi = X_bmi.reshape(-1,1)

plt.scatter(X_bmi, y, s = 25, color = 'blue')

plt.ylabel('Blood Glucose (mg/dl)')

plt.xlabel('Body Mass Index')

#plt.grid(True)

plt.show()
# Out:
# (768, 7)

# %%
diabetes_df = diabetes_df[diabetes_df["glucose"] != 0]
diabetes_df = diabetes_df[diabetes_df["bmi"] != 0]

diabetes_df
# Out:
#      pregnancies  glucose  triceps  insulin   bmi  age  diabetes
# 0              6      148       35        0  33.6   50         1
# 1              1       85       29        0  26.6   31         0
# 2              8      183        0        0  23.3   32         1
# 3              1       89       23       94  28.1   21         0
# 4              0      137       35      168  43.1   33         1
# ..           ...      ...      ...      ...   ...  ...       ...
# 763           10      101       48      180  32.9   63         0
# 764            2      122       27        0  36.8   27         0
# 765            5      121       23      112  26.2   30         0
# 766            1      126        0        0  30.1   47         1
# 767            1       93       31        0  30.4   23         0
#
# [752 rows x 7 columns]

# %%
print(diabetes_df.shape)

X = diabetes_df.drop('glucose', axis=1).values # drop whole glucose column

y = diabetes_df['glucose'].values

X_bmi = X[:,3]

X_bmi = X_bmi.reshape(-1,1)

plt.scatter(X_bmi, y, s = 25, color = 'blue')

plt.ylabel('Blood Glucose (mg/dl)')

plt.xlabel('Body Mass Index')

#plt.grid(True)

plt.show()
# Out:
# (752, 7)

# %%
from sklearn.linear_model import LinearRegression


reg = LinearRegression()
reg.fit(X_bmi, y)
prediction = reg.predict(X_bmi)

plt.scatter(X_bmi, y)
plt.plot(X_bmi, prediction)
plt.ylabel("Blood Glucose (mg/dl)")
plt.xlabel("Body Mass Index")
plt.show()

# %%
sale_df = pd.read_csv("data_sets/sales_df.csv", index_col=0)
sale_df
# Out:
#            tv     radio  social_media      sales
# 0     16000.0   6566.23       2907.98   54732.76
# 1     13000.0   9237.76       2409.57   46677.90
# 2     41000.0  15886.45       2913.41  150177.83
# 3     83000.0  30020.03       6922.30  298246.34
# 4     15000.0   8437.41       1406.00   56594.18
# ...       ...       ...           ...        ...
# 4541  26000.0   4472.36        717.09   94685.87
# 4542  71000.0  20610.69       6545.57  249101.92
# 4543  44000.0  19800.07       5096.19  163631.46
# 4544  71000.0  17534.64       1940.87  253610.41
# 4545  42000.0  15966.69       5046.55  148202.41
#
# [4546 rows x 4 columns]

# %%
x = sale_df['radio'].values
y = sale_df['sales'].values

x = x.reshape(-1,1)
print(x.shape, y.shape)

# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42, stratify=y)
# Out:
# (4546, 1) (4546,)

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(x, y)
prediction = reg.predict(x)

plt.scatter(x, y, color = 'blue')
plt.plot(x, prediction, color='red')
plt.ylabel("Sales ($)")
plt.xlabel("Radio Expenditure ($)")
plt.show()
